# %%
import googletrans
translator = googletrans.Translator()
gi = 'आप क्या कर रहे हैं'
text_to_translate = translator.translate(gi, dest='en', src='hi',)
text = text_to_translate.text
print(text)
# Out:
# What are you doing

# %%
# ENGLISH
import speech_recognition as sr
import time as t
import datetime as dt
import webbrowser
import pywhatkit
import openai
import os
import cv2
import googletrans
translator = googletrans.Translator()

r = sr.Recognizer()
print("NAME :")
# !say "Tell your name to start a chat"
with sr.Microphone() as source:
    print("Listening...")
    audio = r.record(source,duration=3)
    # r.pause_threshold = 8

    # audio = r.listen(source, timeout=8)
try:
    name = r.recognize_google(audio)
    print("You asked:", name)
except sr.UnknownValueError:
    print("Sorry, I couldn't understand.")
    # !say "Sorry, I couldn't understand."
except sr.RequestError:
    print("Sorry, an error occurred during speech recognition.")
    # !say "Sorry, an error occurred during speech recognition."
time = t.strftime('%H:%M:%S')

h = int(t.strftime('%H'))
m = int(t.strftime('%M'))
s = int(t.strftime('%S'))
if (0 < h < 12):
    print(f"goodmorning {name}")
    # !say "good morning! ", {name}
elif (12 <= h < 17):
    print(f"goodafternoon {name}")
    # !say "good afternoon! ", {name}
else:
    print(f"goodevening {name}")
    # !say "good evening! ", {name}
print("how can I help you?")
# !say "how can I help you?"

with sr.Microphone() as source:
    print("Listening...")
    audio = r.record(source,duration=3)
    # r.pause_threshold = 8

    # audio = r.listen(source, timeout=8)
try:
    statement = r.recognize_google(audio)
    print("You asked:", statement)
except sr.UnknownValueError:
    print("Sorry, I couldn't understand.")
    # !say "Sorry, I couldn't understand."
except sr.RequestError:
    print("Sorry, an error occurred during speech recognition.")
    # !say "Sorry, an error occurred during speech recognition."


while statement != "":
    if ("is your name" in statement):
        print("my name is V bot, i am here to assist you")
        # !say "my name is V bot, i am here to assist you"

    elif ("no" in statement or "bye" in statement or "goodbye" in statement or "thankyou" in statement):
        print("I hope this information was suitable for you. Goodbye!")
        # !say "I hope this information was suitable for you. Goodbye!"
        break

    elif ("my name" in statement):
        print(f"yes i know you Mr. {name}")
        # !say "yes i know you Mr", {name}

    elif ("current time" in statement):
        print("time is ", time)
        # !say "time is", {h}, "hours"
        # !say "and ", {m}, "minutes"

    elif ("who made you" in statement or "who created you" in statement):
        print("i am designed and programmed by archit gupta")
        # !say "i am designed and programmed by archit gupta"

    elif ("who are you" in statement or "can you do" in statement or "cappable of" in statement):
        print("i am V bot designed to solve your queries. you can ask me anything like what is your name? , who made you?, what can you do? etc ")
        # !say "i am V bot designed to solve your queries. you can ask me anything like what is your name? , who made you?, what can you do? etc "

    elif ("Google" in statement or "browser" in statement):
        print("searching on browser...")
        # !say "searching on browser..."
        query = statement
        search = f"https://www.google.com/search?q={query}"
        webbrowser.open(search)
        # !say "these are the following results for your queries"

    elif ("YouTube" in statement):
        print("searching on youtube...")
        # !say "searching on youtube...
        query = statement
        search = "https://www.youtube.com/watch?v=wnHW6o8WMas"
        webbrowser.open(search)
        # !say "these are the following results for your queries"

    elif ("Gmail" in statement):
        print("searching...")
        # !say "searching..."
        query = statement
        search = "https://mail.google.com/mail/u/0/?tab=rm&ogbl#inbox"
        webbrowser.open(search)
        # !say "these are the following results for your queries"

    elif ("WhatsApp" in statement):
        print("enter a phone number whom you want to send a message")
        # !say "enter a phone number whom you want to send a message"
        number = input()
        print("enter a message you want to send")
        # !say "enter a message you want to send"
        mssg = input()
        pywhatkit.sendwhatmsg_instantly(f"+91{number}", mssg, 12)

    elif ("chat GPT" in statement):

        api_key = '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'
        openai.api_key = api_key

        print("what do you want to search?")
        # !say "what do you want to search?"
        with sr.Microphone() as source:
            print("Listening...")
            audio = r.record(source,duration=5)
    # r.pause_threshold = 8

    # audio = r.listen(source, timeout=8)
        try:
            search = r.recognize_google(audio)
            print("You asked:", search)
        except sr.UnknownValueError:
            print("Sorry, I couldn't understand.")
            # !say "Sorry, I couldn't understand."
        except sr.RequestError:
            print("Sorry, an error occurred during speech recognition.")
            # !say "Sorry, an error occurred during speech recognition."
        # search = input()

        prompt = f'Search: {search}\nResponse:'

        response = openai.Completion.create(
            engine='text-davinci-003',
            prompt=prompt,
            max_tokens=50
        )

        search_results = response.choices[0].text.strip()
        print("you asked", search)
        # !say "you asked", {search}
        # !say "solution for your query is "
        print(search_results)
        # !say {search_results}

    elif ("camera" in statement):
        cap = cv2.VideoCapture(1)
        while True:
            ret, frame = cap.read()
            cv2.imshow('Camera', frame)
            if cv2.waitKey(1) & 0xFF == ord('q'):
                break

        cap.release()
        cv2.destroyAllWindows()

    print("Do you need any other help ?")
    # !say "Do you need any other help ?"
    with sr.Microphone() as source:
        print("Listening...")
        audio = r.record(source,duration=5)
        # r.pause_threshold = 2
        # audio = r.listen(source, timeout=2)
    try:
        statement = r.recognize_google(audio)
        print("You asked:", statement)
    except sr.UnknownValueError:
        print("Sorry, I couldn't understand.")
        # !say "Sorry, I couldn't understand."
    except sr.RequestError:
        print("Sorry, an error occurred during speech recognition.")
        # !say  "Sorry, an error occurred during speech recognition."
# Out:
# NAME :
# Listening...
# You asked: Raghav
# goodafternoon Raghav
# how can I help you?
# Listening...
# You asked: what can you do sex
# i am V bot designed to solve your queries. you can ask me anything like what is your name? , who made you?, what can you do? etc
# Do you need any other help ?
# Listening...
# You asked: yes I love you
# Do you need any other help ?
# Listening...
# You asked: homemade Yog
# Do you need any other help ?
# Listening...
# You asked: who made you
# i am designed and programmed by archit gupta
# Do you need any other help ?
# Listening...
# You asked: open chat GPT
# what do you want to search?
# Listening...
# You asked: how many states are there in India
# you asked how many states are there in India
# There are 28 states and 8 union territories in India.
# Do you need any other help ?
# Listening...
# You asked: Raat Hai Kaun si
# Do you need any other help ?
# Listening...
# You asked: open GPT
# Do you need any other help ?
# Listening...
# ...

# %%
import cv2

cap = cv2.VideoCapture(0)
while True:
    ret, frame = cap.read()
    cv2.imshow('Camera', frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
pywhatkit.sendwhatmsg_instantly(f"+919667402039", "hi", 20)

# %%
# HINDI
import speech_recognition as sr
import time as t
import datetime as dt
import webbrowser
import pywhatkit
import openai
import os
import googletrans
translator = googletrans.Translator()

r = sr.Recognizer()
print("चैट शुरू करने के लिए अपना नाम दर्ज करें:")
# !say "चैट शुरू करने के लिए अपना नाम दर्ज करें:"
with sr.Microphone() as source:
    print("वीबॉट सुन रहा है...")
    audio = r.record(source,duration=5)
    try:
        name = r.recognize_google(audio, language="hi-IN")
        print("आपका पूछा हुआ सवाल : ", name)
    except sr.UnknownValueError:
        print("ऑडियो समझ में नहीं आया")
        # !say "ऑडियो समझ में नहीं आया"
    except sr.RequestError as e:
        print("क्षमा करें, वाक् पहचान के दौरान एक त्रुटि उत्पन्न हुई।", str(e))
        # !say "क्षमा करें, वाक् पहचान के दौरान एक त्रुटि उत्पन्न हुई।", {e}
text_to_translate = translator.translate(name, dest='en', src='hi',)
text = text_to_translate.text
print("in english : ",text)

time = t.strftime('%H:%M:%S')

h = int(t.strftime('%H'))
m = int(t.strftime('%M'))
s = int(t.strftime('%S'))
if (0 < h < 12):
    print(f"शुभ प्रभात! {name}")
    # !say "शुभ प्रभात! ", {name}
elif (12 <= h < 17):
    print(f"नमस्कार! {name}")
    # !say "नमस्कार! ", {name}
else:
    print(f"नमस्ते! {name}")
    # !say "नमस्ते! ", {name}
print("मैं आपकी कैसे मदद कर सकता हूँ?")
# !say "मैं आपकी कैसे मदद कर सकता हूँ?"


r = sr.Recognizer()

with sr.Microphone() as source:
    print("वीबॉट सुन रहा है...")
    audio = r.record(source,duration=5)
    try:
        statement = r.recognize_google(audio, language="hi-IN")
        print("आपका पूछा हुआ सवाल : ", statement)
    except sr.UnknownValueError:
        print("ऑडियो समझ में नहीं आया")
        # !say "ऑडियो समझ में नहीं आया"
    except sr.RequestError as e:
        print("क्षमा करें, वाक् पहचान के दौरान एक त्रुटि उत्पन्न हुई।", str(e))
        # !say "क्षमा करें, वाक् पहचान के दौरान एक त्रुटि उत्पन्न हुई।", {e}
text_to_translate1 = translator.translate(statement, dest='en', src='hi',)
text1 = text_to_translate1.text
print("in english : ",text1)

while statement != "":
    if ("is your name" in text1):
        print("मेरा नाम वी बॉट है, मैं आपकी सहायता के लिए यहां हूं")
        # !say "मेरा नाम वी बॉट है, मैं आपकी सहायता के लिए यहां हूं"

    elif ("No" in text1 or "bye" in text1 or "goodbye" in text1 or "thankyou" in text1):
        print("मुझे आशा है कि यह जानकारी आपके लिए उपयुक्त होगी। अलविदा!")
        # !say "मुझे आशा है कि यह जानकारी आपके लिए उपयुक्त होगी। अलविदा!"
        break

    elif ("my name" in text1 or "know me" in text1):
        print(f"हाँ मैं आपको जानता हूँ श्रीमान {name}")
        # !say "हाँ मैं आपको जानता हूँ श्रीमान ", {name}

    elif ("time" in text1):
        print("समय है ", time)
        # !say "समय है", {h}, "घंटे"
        # !say "और ", {m}, "मिनट"

    elif ("Who made you" in text1 or "who created you" in text1):
        print("मैं अर्चित गुप्ता द्वारा डिज़ाइन और प्रोग्राम किया गया हूं")
        # !say "मैं अर्चित गुप्ता द्वारा डिज़ाइन और प्रोग्राम किया गया हूं"

    elif ("Who are you" in text1 or "can you do" in text1 or "cappable of" in text1):
        print("मैं वी बॉट हूं जिसे आपके प्रश्नों को हल करने के लिए डिज़ाइन किया गया है। आप मुझसे कुछ भी पूछ सकते हैं जैसे आपका नाम क्या है? , तुम्हें किसने बनाया?, तुम क्या कर सकते हो? वगैरह")
        # !say "मैं वी बॉट हूं जिसे आपके प्रश्नों को हल करने के लिए डिज़ाइन किया गया है। आप मुझसे कुछ भी पूछ सकते हैं जैसे आपका नाम क्या है? , तुम्हें किसने बनाया?, तुम क्या कर सकते हो? वगैरह"

    elif ("Google" in text1 or "browser" in text1):
        print("ब्राउज़र पर खोज रहा हूँ...")
        # !say "ब्राउज़र पर खोज रहा हूँ..."
        query = text1
        search = f"https://www.google.com/search?q={query}"
        webbrowser.open(search)
        # !say "ये आपके प्रश्नों के लिए निम्नलिखित परिणाम हैं"

    elif ("YouTube" in text1):
        print("यूट्यूब पर खोज रहे हैं...")
        # !say "यूट्यूब पर खोज रहे हैं..."
        query = statement
        search = "https://www.youtube.com/watch?v=wnHW6o8WMas"
        webbrowser.open(search)
        # !say "ये आपके प्रश्नों के लिए निम्नलिखित परिणाम हैं"

    elif ("gmail" in text1):
        print("खोज रहे है...")
        # !say "खोज रहे है..."
        query = statement
        search = "https://mail.google.com/mail/u/0/?tab=rm&ogbl#inbox"
        webbrowser.open(search)
        # !say "ये आपके प्रश्नों के लिए निम्नलिखित परिणाम हैं"

    elif ("WhatsApp" in text1):
        print("वह फ़ोन नंबर दर्ज करें जिसे आप संदेश भेजना चाहते हैं")
        # !say "वह फ़ोन नंबर दर्ज करें जिसे आप संदेश भेजना चाहते हैं"
        number = input()
        print("वह संदेश दर्ज करें जिसे आप भेजना चाहते हैं")
        # !say "वह संदेश दर्ज करें जिसे आप भेजना चाहते हैं"
        mssg = input()
        pywhatkit.sendwhatmsg_instantly(f"+91{number}", mssg, 12)

    elif ("chat gPT" in text1):

        api_key = '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'
        openai.api_key = api_key

        print("आप क्या खोजना चाहते हैं?")
        # !say "आप क्या खोजना चाहते हैं?"
        with sr.Microphone() as source:
            print("वीबॉट सुन रहा है...")
            audio = r.record(source,duration=5)
        try:
            test = r.recognize_google(audio, language="hi-IN")
            print("आपका पूछा हुआ सवाल : ", test)
        except sr.UnknownValueError:
            print("ऑडियो समझ में नहीं आया")
            # !say "ऑडियो समझ में नहीं आया"
        except sr.RequestError as e:
            print("क्षमा करें, वाक् पहचान के दौरान एक त्रुटि उत्पन्न हुई।", str(e))
            # !say "क्षमा करें, वाक् पहचान के दौरान एक त्रुटि उत्पन्न हुई।", {e}

        prompt = f'Search: {test}\nResponse:'

        response = openai.Completion.create(
            engine='text-davinci-003',  # Choose the appropriate engine for your use case
            prompt=prompt,
            max_tokens=50  # Set the desired length of the response
        )

        search_results = response.choices[0].text.strip()
        print("आपका पूछा हुआ सवाल : ", test)
        # !say "आपका पूछा हुआ सवाल : ", {test}
        # !say "आपकी क्वेरी का समाधान है"
        print(search_results)
        # !say {search_results}

    print("क्या आपको किसी अन्य सहायता की आवश्यकता है?")
    # !say "क्या आपको किसी अन्य सहायता की आवश्यकता है?"
    with sr.Microphone() as source:
        print("वीबॉट सुन रहा है...")
        audio = r.record(source,duration=5)
    try:
        statement = r.recognize_google(audio, language="hi-IN")
        print("आपका पूछा हुआ सवाल : ", statement)
    except sr.UnknownValueError:
        print("ऑडियो समझ में नहीं आया")
        # !say "ऑडियो समझ में नहीं आया"
    except sr.RequestError as e:
        print("क्षमा करें, वाक् पहचान के दौरान एक त्रुटि उत्पन्न हुई।", str(e))
        # !say "क्षमा करें, वाक् पहचान के दौरान एक त्रुटि उत्पन्न हुई।", {e}
    text_to_translate1 = translator.translate(statement, dest='en', src='hi',)
    text1 = text_to_translate1.text
    print("in english : ",text1)
# Out:
# चैट शुरू करने के लिए अपना नाम दर्ज करें:
# वीबॉट सुन रहा है...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 17
#      15 with sr.Microphone() as source:
#      16     print("वीबॉट सुन रहा है...")
# ---> 17     audio = r.record(source,duration=5)
#      18     try:
#      19         name = r.recognize_google(audio, language="hi-IN")
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/speech_recognition/__init__.py:361, in Recognizer.record(self, source, duration, offset)
#     358     if offset_time > offset:
#     359         offset_reached = True
# --> 361 buffer = source.stream.read(source.CHUNK)
#     362 if len(buffer) == 0: break
#     364 if offset_reached or not offset:
#
# ...

# %%
import speech_recognition as sr

r = sr.Recognizer()

with sr.Microphone() as source:
    print("Speak now...")
    audio = r.listen(source)
    try:
        text = r.recognize_google(audio, language="hi-IN")
        print("Transcription:", text)
    except sr.UnknownValueError:
        print("Could not understand audio")
    except sr.RequestError as e:
        print("Error:", str(e))
# Out:
# Speak now...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 9
#       7 audio = r.listen(source)
#       8 try:
# ----> 9     text = r.recognize_google(audio, language="hi-IN")
#      10     print("Transcription:", text)
#      11 except sr.UnknownValueError:
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/speech_recognition/__init__.py:708, in Recognizer.recognize_google(self, audio_data, key, language, pfilter, show_all, with_confidence)
#     706 # obtain audio transcription results
#     707 try:
# --> 708     response = urlopen(request, timeout=self.operation_timeout)
#     709 except HTTPError as e:
#     710     raise RequestError("recognition request failed: {}".format(e.reason))
#
# ...

# %%
import pywhatkit

# Send a WhatsApp message
# Replace with the recipient's phone number (including the country code)
phone_number = "+919953109602"
message = "Your message goes here"

pywhatkit.sendwhatmsg(phone_number, message, 8, 2)
# Out:
# In 43142 Seconds WhatsApp will open and after 15 Seconds Message will be Delivered!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 7
#       4 phone_number = "+919953109602"  # Replace with the recipient's phone number (including the country code)
#       5 message = "Your message goes here"
# ----> 7 pywhatkit.sendwhatmsg(phone_number, message,8,2)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pywhatkit/whats.py:72, in sendwhatmsg(phone_no, message, time_hour, time_min, wait_time, tab_close, close_time)
#      68 sleep_time = left_time.seconds - wait_time
#      69 print(
#      70     f"In {sleep_time} Seconds WhatsApp will open and after {wait_time} Seconds Message will be Delivered!"
#      71 )
# ---> 72 time.sleep(sleep_time)
# ...

# %%
import webbrowser

query = "your search query"
search_url = f"https://www.google.com/search?q={query}"

# Open the search URL in the default browser
webbrowser.open(search_url)
# Out:
# True
